# %%
# STOPWORD REMOVAL

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "Artificial intelligence is transforming industries by automating tasks."

stop_words = set(stopwords.words('english'))

tokens = word_tokenize(text)

filtered = [word for word in tokens if word.lower() not in stop_words]

print(filtered)
# Out:
# ['Artificial', 'intelligence', 'transforming', 'industries', 'automating', 'tasks', '.']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "Data science helps organizations make better decisions by analyzing large amounts of information."

stop_words = set(stopwords.words('english'))

tokens = word_tokenize(text)

filtered = [word for word in tokens if word.lower() not in stop_words]

print(filtered)
# Out:
# ['Data', 'science', 'helps', 'organizations', 'make', 'better', 'decisions', 'analyzing', 'large', 'amounts', 'information', '.']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "Natural language processing allows computers to understand and generate human language, improving communication between humans and machines."

stop_words = set(stopwords.words('english'))

tokens = word_tokenize(text)

filtered = [word for word in tokens if word.lower() not in stop_words]

print(filtered)
# Out:
# ['Natural', 'language', 'processing', 'allows', 'computers', 'understand', 'generate', 'human', 'language', ',', 'improving', 'communication', 'humans', 'machines', '.']

# %%
# USING SPACY

import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("Artificial intelligence is transforming industries by automating tasks.")

filtered = [token.text for token in doc if not token.is_stop]

print(filtered)
# Out:
# ['Artificial', 'intelligence', 'transforming', 'industries', 'automating', 'tasks', '.']

# %%
# USING SPACY

import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("The rapid growth of technology is changing how people work and communicate.")

filtered = [token.text for token in doc if not token.is_stop]

print(filtered)
# Out:
# ['rapid', 'growth', 'technology', 'changing', 'people', 'work', 'communicate', '.']

# %%
# USING SPACY

import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("Many companies are adopting cloud computing to improve flexibility, reduce costs, and increase scalability across their systems.")

filtered = [token.text for token in doc if not token.is_stop]

print(filtered)
# Out:
# ['companies', 'adopting', 'cloud', 'computing', 'improve', 'flexibility', ',', 'reduce', 'costs', ',', 'increase', 'scalability', 'systems', '.']
