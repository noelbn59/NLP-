# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\noelb\AppData\Roaming\nltk_data...
# True

# %%
# LEMMATIZATION


from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("running", pos="v"))  # verb
print(lemmatizer.lemmatize("better", pos="a"))   # adjective
# Out:
# run
# good

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("The children were happily running and playing in the garden")

for token in doc:
    print(token.text, "->", token.lemma_)
# Out:
# The -> the
# children -> child
# were -> be
# happily -> happily
# running -> run
# and -> and
# playing -> play
# in -> in
# the -> the
# garden -> garden

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("Technology is rapidly changing, influencing how people communicate, learn, and work in modern society")

for token in doc:
    print(token.text, "->", token.lemma_)
# Out:
# Technology -> technology
# is -> be
# rapidly -> rapidly
# changing -> change
# , -> ,
# influencing -> influence
# how -> how
# people -> people
# communicate -> communicate
# , -> ,
# learn -> learn
# , -> ,
# and -> and
# work -> work
# in -> in
# modern -> modern
# society -> society

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("""
Artificial intelligence is transforming industries by automating repetitive tasks,
improving decision-making, and enabling new forms of creativity. Companies are 
increasingly relying on machine learning models to analyze data, predict trends, 
and enhance customer experiences.
""")

for token in doc:
    print(token.text, "->", token.lemma_)
# Out:
#  ->
#
# Artificial -> artificial
# intelligence -> intelligence
# is -> be
# transforming -> transform
# industries -> industry
# by -> by
# automating -> automate
# repetitive -> repetitive
# tasks -> task
# , -> ,
#
#  ->
#
# improving -> improve
# decision -> decision
# - -> -
# making -> making
# , -> ,
# and -> and
# enabling -> enable
# new -> new
# forms -> form
# of -> of
# creativity -> creativity
# . -> .
# Companies -> company
# are -> be
#
#  ->
#
# increasingly -> increasingly
# relying -> rely
# on -> on
# machine -> machine
# learning -> learning
# models -> model
# to -> to
# analyze -> analyze
# data -> datum
# , -> ,
# predict -> predict
# trends -> trend
# , -> ,
#
#  ->
#
# and -> and
# enhance -> enhance
# customer -> customer
# experiences -> experience
# . -> .
#
#  ->
