# %%
# pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\noelb\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\noelb\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\noelb\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\noelb\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\noelb\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\noelb\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
#cleaning


import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

text = "Hello!! Visit https://example.com for more info. This is a SIMPLE example, 2025 :)"

# lowercase
text = text.lower()

# remove urls
text = re.sub(r'http\S+|www\S+', '', text)

# remove numbers
text = re.sub(r'\d+', '', text)

# remove punctuation 
text = re.sub(r'[^\w\s]', '', text)

# remove extra spaces
text = " ".join(text.split())

# remove stopwords
stop_words = set(stopwords.words("english"))
text = " ".join([word for word in text.split() if word not in stop_words])

print(text)
# Out:
# hello visit info simple example
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\noelb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Tokenization

import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize

text = "Hello! How are you doing today?"

print(word_tokenize(text))
# Out:
# ['Hello', '!', 'How', 'are', 'you', 'doing', 'today', '?']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\noelb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\noelb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
#Tokenization



import nltk
from nltk.tokenize import word_tokenize

# force reload of punkt
nltk.data.find("tokenizers/punkt")
nltk.data.find("tokenizers/punkt_tab")

text = "Hello! How are you doing today?"
print(word_tokenize(text))
# Out:
# ['Hello', '!', 'How', 'are', 'you', 'doing', 'today', '?']

# %%
#Sentance tokenization

import nltk
from nltk.tokenize import sent_tokenize

# nltk.download('punkt')
# nltk.download('punkt_tab')
nltk.data.find("tokenizers/punkt")
nltk.data.find("tokenizers/punkt_tab")


text = "Hello there. I am learning NLP! Tokenization is easy, right?"

print(sent_tokenize(text))
# Out:
# ['Hello there.', 'I am learning NLP!', 'Tokenization is easy, right?']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\noelb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\noelb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
